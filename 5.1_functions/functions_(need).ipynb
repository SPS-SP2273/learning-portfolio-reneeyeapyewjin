# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Functions (Need)</span></div>

# %% [markdown]
# # What to expect in this chapter

# %% [markdown]
# # 1 User-defined functions

# %%
conda install matplotlib -c conda-forge
# Out:
# 2 channel Terms of Service accepted
# Retrieving notices: done
# Channels:
#  - conda-forge
#  - defaults
# Platform: osx-arm64
# Collecting package metadata (repodata.json): done
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /Applications/miniconda3
#
#   added / updated specs:
#     - matplotlib
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     brotli-1.1.0               |       h5505292_3          20 KB  conda-forge
#     brotli-bin-1.1.0           |       h5505292_3          17 KB  conda-forge
#     contourpy-1.3.0            |  py313hc846e5e_2         246 KB  conda-forge
#     cycler-0.12.1              |     pyhd8ed1ab_1          13 KB  conda-forge
#     fonttools-4.59.2           |  py313ha0c97b7_0         2.7 MB  conda-forge
#     freetype-2.10.4            |       h17b34a0_1         874 KB  conda-forge
#     jpeg-9e                    |       h1a8c8d9_3         213 KB  conda-forge
#     kiwisolver-1.4.7           |  py313hf9c7212_0          60 KB  conda-forge
#     lcms2-2.16                 |       he26ebf3_1         238 KB
#     lerc-4.0.0                 |       h9a09cb3_0         211 KB  conda-forge
#     libbrotlicommon-1.1.0      |       h5505292_3          67 KB  conda-forge
#     libbrotlidec-1.1.0         |       h5505292_3          29 KB  conda-forge
#     libbrotlienc-1.1.0         |       h5505292_3         268 KB  conda-forge
#     libdeflate-1.22            |       hd74edd7_0          53 KB  conda-forge
#     libpng-1.6.39              |       h80987f9_0         283 KB
#     libtiff-4.7.0              |       h91aec0a_0         400 KB
#     libwebp-base-1.6.0         |       h07db88b_0         288 KB  conda-forge
#     matplotlib-3.10.0          |  py313h39782a4_0          17 KB  conda-forge
#     matplotlib-base-3.10.0     |  py313hb68df00_0         8.1 MB
#     munkres-1.1.4              |     pyhd8ed1ab_1          15 KB  conda-forge
#     openjpeg-2.5.2             |       hba36e21_1         322 KB
#     pillow-11.1.0              |  py313h41ba818_1         912 KB
#     pyparsing-3.2.3            |     pyhe01879c_2         100 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        15.3 MB
#
# The following NEW packages will be INSTALLED:
#
#   brotli             conda-forge/osx-arm64::brotli-1.1.0-h5505292_3
#   brotli-bin         conda-forge/osx-arm64::brotli-bin-1.1.0-h5505292_3
#   contourpy          conda-forge/osx-arm64::contourpy-1.3.0-py313hc846e5e_2
#   cycler             conda-forge/noarch::cycler-0.12.1-pyhd8ed1ab_1
#   fonttools          conda-forge/osx-arm64::fonttools-4.59.2-py313ha0c97b7_0
#   freetype           conda-forge/osx-arm64::freetype-2.10.4-h17b34a0_1
#   jpeg               conda-forge/osx-arm64::jpeg-9e-h1a8c8d9_3
#   kiwisolver         conda-forge/osx-arm64::kiwisolver-1.4.7-py313hf9c7212_0
#   lcms2              pkgs/main/osx-arm64::lcms2-2.16-he26ebf3_1
#   lerc               conda-forge/osx-arm64::lerc-4.0.0-h9a09cb3_0
#   libbrotlicommon    conda-forge/osx-arm64::libbrotlicommon-1.1.0-h5505292_3
#   libbrotlidec       conda-forge/osx-arm64::libbrotlidec-1.1.0-h5505292_3
#   libbrotlienc       conda-forge/osx-arm64::libbrotlienc-1.1.0-h5505292_3
#   libdeflate         conda-forge/osx-arm64::libdeflate-1.22-hd74edd7_0
#   libpng             pkgs/main/osx-arm64::libpng-1.6.39-h80987f9_0
#   libtiff            pkgs/main/osx-arm64::libtiff-4.7.0-h91aec0a_0
#   libwebp-base       conda-forge/osx-arm64::libwebp-base-1.6.0-h07db88b_0
#   matplotlib         conda-forge/osx-arm64::matplotlib-3.10.0-py313h39782a4_0
#   matplotlib-base    pkgs/main/osx-arm64::matplotlib-base-3.10.0-py313hb68df00_0
#   munkres            conda-forge/noarch::munkres-1.1.4-pyhd8ed1ab_1
#   openjpeg           pkgs/main/osx-arm64::openjpeg-2.5.2-hba36e21_1
#   pillow             pkgs/main/osx-arm64::pillow-11.1.0-py313h41ba818_1
#   pyparsing          conda-forge/noarch::pyparsing-3.2.3-pyhe01879c_2
#
#
#
# Downloading and Extracting Packages:
# matplotlib-base-3.10 | 8.1 MB    |                                       |   0%
# fonttools-4.59.2     | 2.7 MB    |                                       |   0%
#
# pillow-11.1.0        | 912 KB    |                                       |   0%
#
#
# freetype-2.10.4      | 874 KB    |                                       |   0%
#
#
#
# libtiff-4.7.0        | 400 KB    |                                       |   0%
#
#
#
#
# openjpeg-2.5.2       | 322 KB    |                                       |   0%
#
#
#
#
#
# libwebp-base-1.6.0   | 288 KB    |                                       |   0%
#
#
#
#
#
#
# libpng-1.6.39        | 283 KB    |                                       |   0%
#
#
#
#
#
#
#
# libbrotlienc-1.1.0   | 268 KB    |                                       |   0%
#
#
#
#
#
#
#
#
# contourpy-1.3.0      | 246 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 213 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 211 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.3      | 100 KB    |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.1. | 67 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.7     | 60 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 53 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.1.0   | 29 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.1.0         | 20 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.1.0     | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.10.0    | 17 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munkres-1.1.4        | 15 KB     |                                       |   0%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.12.1        | 13 KB     |                                       |   0%
#
#
# freetype-2.10.4      | 874 KB    | ############8                         |  35%
#
# pillow-11.1.0        | 912 KB    | 6                                     |   2%
# fonttools-4.59.2     | 2.7 MB    | 2                                     |   1%
#
#
#
# matplotlib-base-3.10 | 8.1 MB    |                                       |   0%
#
#
# freetype-2.10.4      | 874 KB    | ##################################### | 100%
#
# pillow-11.1.0        | 912 KB    | ###############5                      |  42%
# fonttools-4.59.2     | 2.7 MB    | #2                                    |   3%
#
#
# freetype-2.10.4      | 874 KB    | ##################################### | 100%
#
#
# matplotlib-base-3.10 | 8.1 MB    | 8                                     |   2%
#
#
#
# libtiff-4.7.0        | 400 KB    | ########8                             |  24%
#
# pillow-11.1.0        | 912 KB    | #################################1    |  89%
# fonttools-4.59.2     | 2.7 MB    | ######9                               |  19%
#
# pillow-11.1.0        | 912 KB    | ##################################### | 100%
#
# pillow-11.1.0        | 912 KB    | ##################################### | 100%
#
#
#
# libtiff-4.7.0        | 400 KB    | ##################################### | 100%
#
#
#
# libtiff-4.7.0        | 400 KB    | ##################################### | 100%
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | ###5                                  |  10%
# fonttools-4.59.2     | 2.7 MB    | ##############6                       |  40%
#
#
#
#
# openjpeg-2.5.2       | 322 KB    | #8                                    |   5%
#
#
#
#
#
#
# libpng-1.6.39        | 283 KB    | ##                                    |   6%
# matplotlib-base-3.10 | 8.1 MB    | ######2                               |  17%
#
#
#
#
#
# libwebp-base-1.6.0   | 288 KB    | ##                                    |   6%
#
#
#
#
#
#
# libpng-1.6.39        | 283 KB    | ##################################### | 100%
#
#
#
#
# openjpeg-2.5.2       | 322 KB    | #############################3        |  79%
#
#
#
#
# openjpeg-2.5.2       | 322 KB    | ##################################### | 100%
#
#
#
#
#
#
# libpng-1.6.39        | 283 KB    | ##################################### | 100%
#
#
#
#
#
#
# libpng-1.6.39        | 283 KB    | ##################################### | 100%
#
#
#
#
# openjpeg-2.5.2       | 322 KB    | ##################################### | 100%
#
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | ########4                             |  23%
#
#
#
#
#
# libwebp-base-1.6.0   | 288 KB    | ##################################### | 100%
# fonttools-4.59.2     | 2.7 MB    | ###########################1          |  73%
#
#
#
#
#
#
#
# libbrotlienc-1.1.0   | 268 KB    | ##2                                   |   6%
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | ##########1                           |  28%
#
#
#
#
#
#
#
#
#
# lcms2-2.16           | 238 KB    | ##################################### | 100%
# fonttools-4.59.2     | 2.7 MB    | ################################      |  87%
#
#
#
#
#
#
#
# libbrotlienc-1.1.0   | 268 KB    | ##################################### | 100%
#
#
#
#
#
#
#
# libbrotlienc-1.1.0   | 268 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# contourpy-1.3.0      | 246 KB    | ##4                                   |   7%
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 213 KB    | ##7                                   |   7%
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | ###########9                          |  32%
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 211 KB    | ##8                                   |   8%
#
#
#
#
#
#
#
#
# contourpy-1.3.0      | 246 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
# jpeg-9e              | 213 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 211 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
# contourpy-1.3.0      | 246 KB    | ##################################### | 100%
# fonttools-4.59.2     | 2.7 MB    | ####################################8 | 100%
# fonttools-4.59.2     | 2.7 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.3      | 100 KB    | #####9                                |  16%
#
#
#
#
#
#
#
#
#
#
#
# lerc-4.0.0           | 211 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.3      | 100 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
# pyparsing-3.2.3      | 100 KB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.1. | 67 KB     | ########7                             |  24%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.1. | 67 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 53 KB     | ###########2                          |  30%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.1.0   | 29 KB     | ####################7                 |  56%
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlicommon-1.1. | 67 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.1.0   | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | ##############4                       |  39%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libbrotlidec-1.1.0   | 29 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# libdeflate-1.22      | 53 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.1.0         | 20 KB     | ##############################1       |  82%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.1.0         | 20 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-1.1.0         | 20 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.1.0     | 17 KB     | ###################################2  |  95%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.1.0     | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# brotli-bin-1.1.0     | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munkres-1.1.4        | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munkres-1.1.4        | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# munkres-1.1.4        | 15 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.12.1        | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.12.1        | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# cycler-0.12.1        | 13 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.7     | 60 KB     | #########8                            |  27%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-base-3.10 | 8.1 MB    | ##################4                   |  50%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# kiwisolver-1.4.7     | 60 KB     | ##################################### | 100%
# matplotlib-base-3.10 | 8.1 MB    | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.10.0    | 17 KB     | ###################################4  |  96%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# matplotlib-3.10.0    | 17 KB     | ##################################### | 100%
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
from matplotlib import pyplot as plt
import random
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
m, c = 3, 4

x_values1 = [x for x in range(10)]
y_values1 = [m*x_value + c + random.random() for x_value in x_values1]

m, c = 6, 2

x_values2 = [x for x in range(10)]
y_values2 = [m*x_value + c + random.random() for x_value in x_values2]

plt.plot(x_values1,y_values1)
plt.plot(x_values2,y_values2)

# %%
def my_line_py(m,c):
    x_values = [x for x in range(100)]
    y_values = [m*x_value + c + random.random() for x_value in x_values]
    return x_values, y_values

def my_line_np(m,c):
    x_values = np.linspace(0,10,10)
    y_values = m*x_values + c + random.random()
    return x_values, y_values

# %%
for m in range(5):
    x,y = my_line_py(m, 0)
    plt.plot(x,y)

# %%
for m in range(5):
    x,y = my_line_np(m, 0)
    plt.plot(x,y)

# %%
def write_data(m,c):
    x_values = np.linspace(0,10,5)
    y_values = m*x_values + c + 5*random.random()
    np.savetxt(f'hahaha_{m=}_{c=}.txt',(x_values,y_values))

write_data(2,3)

# %% [markdown]
# ## 1.1 Named Functions

# %% [markdown]
# ### Named functions that return

# %%
def greeting(name):
    if name == 'Batman':
        return 'Hello Batman! So, nice to meet you!'
    else:
        return f'Hello {name}!'

greeting("Super Man")
# Out:
# 'Hello Super Man!'

# %%
import numpy as np

def basic_stats(numbers):
    np_numbers = np.array(numbers)
    my_min = np_numbers.min()
    my_max = np_numbers.max()
    my_mean = np_numbers.mean()
    return my_max, my_min, my_mean

# %%
basic_stats([1, 2, 3, 4, 5])
# Out:
# (np.int64(5), np.int64(1), np.float64(3.0))

# %% [markdown]
# ### Named functions that don’t return

# %% [markdown]
# ## 1.2 Anonymous functions

# %%
my_short_function = lambda name: f"Hello {name}!"

# %%
my_short_function(name="Super Man")
# Out:
# 'Hello Super Man!'

# %%
numbers=[[9, 0, -10],
         [8, 1, -11],
         [7, 2, -12],
         [6, 3, -13],
         [5, 4, -14],
         [4, 5, -15],
         [3, 6, -16],
         [2, 7, -17],
         [1, 8, -18],
         [0, 9, -19]]

# %%
# Sort by comparing the default key
# (i.e., the 1st element)
sorted(numbers)
# Out:
# [[0, 9, -19],
#  [1, 8, -18],
#  [2, 7, -17],
#  [3, 6, -16],
#  [4, 5, -15],
#  [5, 4, -14],
#  [6, 3, -13],
#  [7, 2, -12],
#  [8, 1, -11],
#  [9, 0, -10]]

# %%
# Sort by comparing a custom key
# that uses the 2nd element (index=1)
sorted(numbers, key=lambda x: x[1])
# Out:
# [[9, 0, -10],
#  [8, 1, -11],
#  [7, 2, -12],
#  [6, 3, -13],
#  [5, 4, -14],
#  [4, 5, -15],
#  [3, 6, -16],
#  [2, 7, -17],
#  [1, 8, -18],
#  [0, 9, -19]]

# %%
# Sort by comparing a custom key
# that uses the sum of the elements.
sorted(numbers, key=lambda x: sum(x))
# Out:
# [[0, 9, -19],
#  [1, 8, -18],
#  [2, 7, -17],
#  [3, 6, -16],
#  [4, 5, -15],
#  [5, 4, -14],
#  [6, 3, -13],
#  [7, 2, -12],
#  [8, 1, -11],
#  [9, 0, -10]]

# %% [markdown]
# ## 1.3 Optional arguments

# %%
def greeting(name='no one'):
    if name == 'Batman':
        return 'Hello Batman! So, nice to meet you!'
    else:
        return f'Hello {name}!'

# %%
greeting()
# Out:
# 'Hello no one!'

# %%
# Using default values
print('I', 'am', 'Batman!')
# Specifying an optional argument
print('I', 'am', 'Batman!', sep='---')
# Out:
# I am Batman!
# I---am---Batman!

# %% [markdown]
# ## 1.4 The importance of functions?

# %% [markdown]
# ### An argument for functions

# %%
# Your code here

# %% [markdown]
# ### A word of caution

# %%
# Your code here
